# %%
# %load_ext autoreload
# %autoreload 2
# from googletrans import Translator
from sentiment.tass import InterTASSReader
import os
from collections import Counter, defaultdict as dc
from copy import deepcopy
from googletrans.constants import LANGUAGES
import pickle
# from google.cloud import translate
from augment_sel import Translator
from tqdm import tqdm

reader = InterTASSReader('intertass-ES-train-tagged.xml')
tweets = list(reader.tweets())

# %%
def make_string(tweets):
    last_i = 0
    str_ = ""
    translated_tweets = []
    for i, tweet in enumerate(tweets):
        translated_tweets.append(deepcopy(tweet))
        str_ += "\n---\n" + tweet["content"]
        if len(str_) >= 4800 or i == len(tweets)-1:
            #print(str_)
            # translation = client.translate_to(str_).split("--\n")
            return str_
            translation = str_.split("\n---\n")
            str_ = ""
            translation.remove("")
            last_i = i
            return
            for idx, tw in enumerate(translated_tweets[last_i:]):
                tw["content"] = translation[idx]
    return translated_tweets

# %%
a = make_string(tweets)
# """|||||||| -Me caes muy bien 
# -Tienes que jugar más partidas al lol con Russel y conmigo
# -Por qué tan Otako, deja de ser otako
# -Haber si me muero|||||||| @myendlesshazza a. que puto mal escribo""".split("||||||||")

# %%
with open("augmented_data.pkl", "rb") as f:
    a = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-c3be86fca159> in <module>
# ----> 1 with open("2augmented_data.pkl", "rb") as f:
#       2     a = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2augmented_data.pkl'

# %%
# [i["content"] for i in a if i["tweetid"] == "768213876278165504"]

# a

# %%
import pandas as pd
b = []
a2= []
for i in a:
    if not i["content"] in b:
        a2.append(i)
        b.append(i["content"])
    
a = pd.DataFrame(a2)
a.sort_values('tweetid', inplace=True)

# %%
len(a)
# Out:
# 3171

# %%
c = a[a["tweetid"] == "757313951738761216"]["content"]
t = pd.DataFrame(tweets)
s = t[t["tweetid"] == "757313951738761216"]
s["content"]
# Out:
# 953    @remardifuck a mi ya se me fueron los 2gb
# Name: content, dtype: object

# %%
from googletrans.constants import LANGUAGES
a = list(LANGUAGES.keys())
a.remove("es")
a.remove('zh-cn')
a.remove('zh-tw')

# %%
import difflib
def xd(a):
#a = 'Es increíble y tal pero no , no voy a ir al TH '
    b = "@remardifuck a mi ya se me fueron los 2gb"

    seq = difflib.SequenceMatcher(None,a,b)
    d = seq.ratio()
#     print(d) 
    return d

# %%
def clean(self, tweets):
    corpus = "intertass-ES-train-tagged.xml"
    reader = InterTASSReader(corpus)
    original_tweets = list(reader.tweets())

    original_tweets = sorted(original_tweets, key=itemgetter('tweetid'))
    tweets = sorted(tweets, key=itemgetter('tweetid'))

    cleaned_data = []

    count = 0
    for or_tw in original_tweets:
        tr_tw = tweets[count]
        while or_tw["tweetid"] == tr_tw["tweetid"]:
            count += 1
            if _distance(or_tw["content"], tr_tw["content"]) > 0.6:
                cleaned_data.extend(tr_tw)

    return cleaned_data

# %%
from sentiment.new_data import InterTASSAugmented
import pandas as pd

reader = InterTASSAugmented("augmented_data.pkl", clean=True, ratio=0.77)  # Class to use augmented data
# 1534   es      NONE  809187289528205315       Dieguiko98
# 1535   es      NONE  810394795160010752        EymiPlaza
# 1536   es      NONE  810394795160010752        EymiPlaza
# 1537   es      NONE  810394795160010752        EymiPlaza
# 1538   es      NONE  810394795160010752        EymiPlaza
# 1539   es      NONE  810394795160010752        EymiPlaza
# 1540   es      NONE  810394795160010752        EymiPlaza
# 1541   es      NONE  810394795160010752        EymiPlaza
# 1542   es      NONE  810394795160010752        EymiPlaza
# 1543   es      NONE  810394795160010752        EymiPlaza
# 1544   es      NONE  810394795160010752        EymiPlaza
# 1545   es      NONE  810394795160010752        EymiPlaza
# 1546   es         N  810494304795983872         sxdpandu
# 1547   es         N  810494304795983872         sxdpandu
# 1548   es         N  810494304795983872         sxdpandu
# 1549   es         N  813731371076243461  GonzaloRoman_91
# 1550   es         N  813731371076243461  GonzaloRoman_91
# 1551   es         N  813731371076243461  GonzaloRoman_91
# 1552   es         P  814846333601320960     jdomperfects
# 1553   es         P  814846333601320960     jdomperfects
# 1554   es         P  814846333601320960     jdomperfects
# 1555   es         P  814846333601320960     jdomperfects
# 1556   es         P  814846333601320960     jdomperfects
# 1557   es         P  814846333601320960     jdomperfects
# 1558   es         P  814846333601320960     jdomperfects
# 1559   es         P  815715581878009858    carmen_ligero
# 1560   es         P  815715581878009858    carmen_ligero
# 1561   es         P  816978031357161476    carmen_ligero
# 1562   es         P  816978031357161476    carmen_ligero
# 1563   es         P  816978031357161476    carmen_ligero
#
# [1564 rows x 6 columns]

# %%
b = a[a["tweetid"] == "755798737373528064"]
set(b["content"])
# Out:
# {'Un AI 100 sería el mejor.',
#  'Un AI The 100 sería lo mejor.',
#  'Un AI The 100 sería lo mejor. '}

# %%
a
# Out:
#                                               content                 date  \
# 0                              Un AI 100 es el mejor.  2016-07-20 16:17:15
# 1                           Un AI 100 sería el mejor.  2016-07-20 16:17:15
# 2                   Un AI Los 100 serían los mejores.  2016-07-20 16:17:15
# 3                              Un AI 100 sería mejor.  2016-07-20 16:17:15
# 4                  Una IA Los 100 serían los mejores.  2016-07-20 16:17:15
# 5                      Un AI The 100 sería lo mejor.   2016-07-20 16:17:15
# 6            Es increíble y así, pero no, no iré a TH  2016-07-24 00:16:25
# 7            Es increíble y tal, pero no, no iré a TH  2016-07-24 00:16:25
# 8     Es increíble y tal pero no , no voy a ir al TH   2016-07-24 00:16:25
# 9         Es increíble y tal, pero no, no voy a la TH  2016-07-24 00:16:25
# 10                  @remardifuck para mi y yo era 2gb  2016-07-24 20:38:10
# 11                  @remardifuck para mí y yo era 2gb  2016-07-24 20:38:10
# 12         @remardifuck a mi ya se me fueron los 2gb   2016-07-24 20:38:10
# 13                         A las 5:30 p.m. el autobús  2016-07-28 11:30:11
# 14                              A las 5:30 pm el bus.  2016-07-28 11:30:11
# 15                              A las 5:30 pm autobús  2016-07-28 11:30:11
# 16                          A las 17:30 pillo el bus   2016-07-28 11:30:11
# 0      es         P  755798737373528064     Noelia_MLuna
# 1      es         P  755798737373528064     Noelia_MLuna
# 2      es         P  755798737373528064     Noelia_MLuna
# 3      es         P  755798737373528064     Noelia_MLuna
# 4      es         P  755798737373528064     Noelia_MLuna
# 5      es         P  755798737373528064     Noelia_MLuna
# 6      es       NEU  757006488388964352       FatimaSiso
# 7      es       NEU  757006488388964352       FatimaSiso
# 8      es       NEU  757006488388964352       FatimaSiso
# 9      es       NEU  757006488388964352       FatimaSiso
# 10     es         N  757313951738761216     dalejandrob_
# 11     es         N  757313951738761216     dalejandrob_
# 12     es         N  757313951738761216     dalejandrob_
# 13     es      NONE  758625596419219456         JonGaxia
# 14     es      NONE  758625596419219456         JonGaxia
# 15     es      NONE  758625596419219456         JonGaxia
# 16     es      NONE  758625596419219456         JonGaxia
# 17     es       NEU  758796085607313408       manal20102
# 18     es       NEU  758796085607313408       manal20102
# 19     es       NEU  758796085607313408       manal20102
# 20     es       NEU  758796085607313408       manal20102
# 21     es       NEU  760040753867395073         almaa_17
# 22     es       NEU  760040753867395073         almaa_17
# 23     es       NEU  760040753867395073         almaa_17
# 24     es       NEU  760040753867395073         almaa_17
# 25     es       NEU  760040753867395073         almaa_17
# 26     es         N  760388682830508032      sugusplanet
# 27     es         N  760388682830508032      sugusplanet
# 28     es         N  760388682830508032      sugusplanet
# 29     es         N  760388682830508032      sugusplanet
# ...   ...       ...                 ...              ...
# 1287   es       NEU  807896881590337536   hatedinbabylon
# 1288   es       NEU  807896881590337536   hatedinbabylon
# 1289   es       NEU  807896881590337536   hatedinbabylon
# 1290   es      NONE  809187289528205315       Dieguiko98
# 1291   es      NONE  809187289528205315       Dieguiko98
# 1292   es      NONE  809187289528205315       Dieguiko98
# 1293   es      NONE  809187289528205315       Dieguiko98
# 1294   es      NONE  809187289528205315       Dieguiko98
# 1295   es      NONE  810394795160010752        EymiPlaza
# 1296   es      NONE  810394795160010752        EymiPlaza
# 1297   es      NONE  810394795160010752        EymiPlaza
# 1298   es      NONE  810394795160010752        EymiPlaza
# 1299   es      NONE  810394795160010752        EymiPlaza
# 1300   es      NONE  810394795160010752        EymiPlaza
# 1301   es         N  810494304795983872         sxdpandu
# 1302   es         N  810494304795983872         sxdpandu
# 1303   es         N  813731371076243461  GonzaloRoman_91
# 1304   es         N  813731371076243461  GonzaloRoman_91
# 1305   es         N  813731371076243461  GonzaloRoman_91
# 1306   es         N  813731371076243461  GonzaloRoman_91
# 1307   es         N  813731371076243461  GonzaloRoman_91
# 1308   es         P  814846333601320960     jdomperfects
# 1309   es         P  814846333601320960     jdomperfects
# 1310   es         P  814846333601320960     jdomperfects
# 1311   es         P  815715581878009858    carmen_ligero
# 1312   es         P  815715581878009858    carmen_ligero
# 1313   es         P  816978031357161476    carmen_ligero
# 1314   es         P  816978031357161476    carmen_ligero
# 1315   es         P  816978031357161476    carmen_ligero
# 1316   es         P  816978031357161476    carmen_ligero
#
# [1317 rows x 6 columns]
